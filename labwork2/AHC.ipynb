# %%
import os
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

X = [[1], [2], [9], [12], [20]]

#Delete the existing png file
if os.path.exists("AHC_X_single.png"):
    os.remove("AHC_X_single.png")

#AHC clustering using Single Linkage on X dataset
Z = linkage(X, 'single')

# Plot the dendrogram for the single linkage
dendrogram(Z)

#Legend for the plot
legend_elements = [Line2D([0], [0], color='blue', lw = 2, label = 'Cluster 1'),
                   Line2D([0], [0], color='orange', lw = 2, label = 'Cluster 2'),
                   Line2D([0], [0], color='green', lw = 2, label = 'Cluster 3')]
plt.legend(handles = legend_elements, loc = 'upper right')

#Save the plot as a png file and display it
plt.savefig('AHC_X_single.png')
plt.title('AHC on X dataset using Single Linkage')
plt.show()
"""
   Explain the dendrogram plot for single linkage
    The dendrogram plot for single linkage shows the distance between the clusters.
    The distance between the clusters is shown on the y-axis and the data points are shown on the x-axis.
    The dendrogram plot shows that the distance between the clusters is increasing as we move up the y-axis.
"""
# Out:
# '\n   Explain the dendrogram plot for single linkage\n    The dendrogram plot for single linkage shows the distance between the clusters.\n    The distance between the clusters is shown on the y-axis and the data points are shown on the x-axis.\n    The dendrogram plot shows that the distance between the clusters is increasing as we move up the y-axis.\n'

# %%
from matplotlib.lines import Line2D

#Delete the existing png file if it exists
if os.path.exists("AHC_X_complete.png"):
    os.remove("AHC_X_complete.png")

#AHC clustering using Complete Linkage on X dataset
Z = linkage(X, 'complete')

# Plot the dendrogram for the Complete linkage
dendrogram(Z)

#Legend for the plot
legend_elements = [Line2D([0], [0], color = 'blue', lw = 2, label = 'Cluster 1'),
                   Line2D([0], [0], color = 'orange', lw=2, label = 'Cluster 2')]
plt.legend(handles = legend_elements, loc = 'upper right')

#Save the plot as a png file and display it
plt.savefig('AHC_X_complete.png')
plt.title('Dendrogram for Complete Linkage on X dataset')
plt.show()
""" 
    Explain the dendrogram plot for complete linkage
    The dendrogram plot for complete linkage shows the distance between the clusters.
    The distance between the clusters is shown on the y-axis and the data points are shown on the x-axis.
    The dendrogram plot shows that the distance between the clusters is increasing as we move up the y-axis.
    The dendrogram plot for complete linkage shows that the distance between the clusters is more than the distance between the clusters in single linkage.
"""
# Out:
# ' \n    Explain the dendrogram plot for complete linkage\n    The dendrogram plot for complete linkage shows the distance between the clusters.\n    The distance between the clusters is shown on the y-axis and the data points are shown on the x-axis.\n    The dendrogram plot shows that the distance between the clusters is increasing as we move up the y-axis.\n    The dendrogram plot for complete linkage shows that the distance between the clusters is more than the distance between the clusters in single linkage.\n'

# %%
# Dataset 1: Iris
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
import os

iris = datasets.load_iris()
X_ir = iris.data
y_ir = iris.target

#Delete the existing png file if it exists
if os.path.exists("AHC_iris_single.png"):
    os.remove("AHC_iris_single.png")

#AHC clustering using Single Linkage on Iris dataset
A = linkage(X_ir, 'single')

# Plot the dendrogram for the single linkage
dendrogram(A, truncate_mode = 'lastp', p = 14)

#Legend for the plot
legend_elements = [Line2D([0], [0], color='blue', lw = 2, label = 'Cluster 1'),
                   Line2D([0], [0], color='orange', lw = 2, label = 'Cluster 2'),
                   Line2D([0], [0], color='green', lw = 2, label = 'Cluster 3')]
plt.legend(handles = legend_elements, loc = 'upper right')


#Save the plot as a png file
plt.savefig('AHC_iris_single.png')
plt.title("AHC clustering using Single Linkage on Iris dataset")
plt.show()

# %%
#Delete the existing png file if it exists
if os.path.exists("AHC_iris_complete.png"):
    os.remove("AHC_iris_complete.png")

#AHC clustering using Complete Linkage on Iris dataset
B = linkage(X_ir, 'complete')

# Plot the dendrogram for the Complete linkage
dendrogram(B, truncate_mode = 'lastp', p = 20)

#Legend for the plot
legend_elements = [Line2D([0], [0], color = 'blue', lw = 2, label = 'Cluster 1'),
                   Line2D([0], [0], color = 'orange', lw=2, label = 'Cluster 2'),
                   Line2D([0], [0], color = 'green', lw=2, label = 'Cluster 3')]
plt.legend(handles = legend_elements, loc = 'upper right')
#Save the plot as a png file
plt.savefig('AHC_iris_complete.png')
plt.title("AHC clustering using Complete Linkage on Iris dataset")
plt.show()

# %%
# Dataset 2: Breast Cancer
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id = 17) 
  
# data (as pandas dataframes) 
X_brst = breast_cancer_wisconsin_diagnostic.data.features 
y_brst = breast_cancer_wisconsin_diagnostic.data.targets 

#Delete the existing png file if it exists
if os.path.exists("AHC_brst_single.png"):
    os.remove("AHC_brst_single.png")

#AHC clustering using Single Linkage on Breast Cancer dataset
C = linkage(X_brst, 'single')

# Plot the dendrogram for the single linkage
dendrogram(C, truncate_mode = 'lastp', p = 10)

#Legend for the plot
legend_elements = [Line2D([0], [0], color='blue', lw = 2, label = 'Cluster 1'),
                   Line2D([0], [0], color='orange', lw = 2, label = 'Cluster 2')]
plt.legend(handles = legend_elements, loc = 'upper right')
#Save the plot as a png file
plt.savefig('AHC_brst_single.png')
plt.title("AHC clustering using Single Linkage on Breast Cancer dataset")
plt.show()

# %%
from matplotlib.lines import Line2D

#Delete the existing png file if it exists
if os.path.exists("AHC_brst_complete.png"):
    os.remove("AHC_brst_complete.png")

#AHC clustering using Complete Linkage on Breast Cancer dataset
D = linkage(X_brst, 'complete')

# Plot the dendrogram for the Complete linkage
dendrogram(D, truncate_mode = 'lastp', p = 20)

#Save the plot as a png file
legend_elements = [Line2D([0], [0], color='b', lw=2, label='Cluster 1'),
                   Line2D([0], [0], color='orange', lw=2, label='Cluster 2'),
                   Line2D([0], [0], color='g', lw=2, label='Cluster 3')]
plt.legend(handles=legend_elements, loc='upper left')
plt.savefig('AHC_brst_complete.png')
plt.title("AHC clustering using Complete Linkage on Breast Cancer dataset")
plt.show()

# %%
#Dataset 3: Diabetes
from ucimlrepo import fetch_ucirepo

# fetch dataset
pima_indians_diabetes = fetch_ucirepo(id = 37)

# data (as pandas dataframes)
X_diab = pima_indians_diabetes.data.features
y_diab = pima_indians_diabetes.data.targets

#Delete the existing png file if it exists
if os.path.exists("AHC_diab_single.png"):
    os.remove("AHC_diab_single.png")

#AHC clustering using Single Linkage on Diabetes dataset
E = linkage(X_diab, 'single')

# Plot the dendrogram for the single linkage
dendrogram(E)

#Save the plot as a png file
legend_elements = [Line2D([0], [0], color='b', lw=2, label='Cluster 1'),
                   Line2D([0], [0], color='orange', lw=2, label='Cluster 2'),
                   Line2D([0], [0], color='g', lw=2, label='Cluster 3')]
plt.legend(handles=legend_elements, loc='upper left')
plt.savefig('AHC_diab_single.png')
plt.title("AHC clustering using Single Linkage on Diabetes dataset")
plt.show()
