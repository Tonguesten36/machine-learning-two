# %%
import os
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

X = [[1], [2], [9], [12], [20]]

#Delete the existing png file
if os.path.exists("AHC_X_single.png"):
    os.remove("AHC_X_single.png")

#AHC clustering using Single Linkage on X dataset
Z = linkage(X, 'single')

# Plot the dendrogram for the single linkage
dendrogram(Z)

#Save the plot as a png file
plt.savefig('AHC_X_single.png')
plt.title('AHC on X dataset using Single Linkage')
plt.show()
"""
   Explain the dendrogram plot for single linkage
    The dendrogram plot for single linkage shows the distance between the clusters.
    The distance between the clusters is shown on the y-axis and the data points are shown on the x-axis.
    The dendrogram plot shows that the distance between the clusters is increasing as we move up the y-axis.
"""
# Out:
# '\n   Explain the dendrogram plot\n   \n'

# %%
#Delete the existing png file if it exists
if os.path.exists("AHC_X_complete.png"):
    os.remove("AHC_X_complete.png")

#AHC clustering using Complete Linkage on X dataset
Z = linkage(X, 'complete')

# Plot the dendrogram for the Complete linkage
dendrogram(Z)

#Save the plot as a png file
plt.savefig('AHC_X_complete.png')
plt.title('Dendrogram for Complete Linkage on X dataset')
plt.show()
""" 
    Explain the dendrogram plot for complete linkage
    The dendrogram plot for complete linkage shows the distance between the clusters.
    The distance between the clusters is shown on the y-axis and the data points are shown on the x-axis.
    The dendrogram plot shows that the distance between the clusters is increasing as we move up the y-axis.
    The dendrogram plot for complete linkage shows that the distance between the clusters is more than the distance between the clusters in single linkage.
"""

# %%
# Dataset 1: Iris
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
import os

iris = datasets.load_iris()
X_ir = iris.data
y_ir = iris.target

#Delete the existing png file if it exists
if os.path.exists("AHC_iris_single.png"):
    os.remove("AHC_iris_single.png")

#AHC clustering using Single Linkage on Iris dataset
A = linkage(X_ir, 'single')

# Plot the dendrogram for the single linkage
dendrogram(A)

#Save the plot as a png file
plt.savefig('AHC_iris_single.png')
plt.title("AHC clustering using Single Linkage on Iris dataset")
plt.show()

# %%
#Delete the existing png file if it exists
if os.path.exists("AHC_iris_complete.png"):
    os.remove("AHC_iris_complete.png")

#AHC clustering using Complete Linkage on Iris dataset
B = linkage(X_ir, 'complete')

# Plot the dendrogram for the Complete linkage
dendrogram(B)

#Save the plot as a png file
plt.savefig('AHC_iris_complete.png')
plt.title("AHC clustering using Complete Linkage on Iris dataset")
plt.show()

# %%
# Dataset 2: Adult
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
adult = fetch_ucirepo(id = 2) 
  
# data (as pandas dataframes) 
X_ad = adult.data 

#Delete the existing png file if it exists
if os.path.exists("AHC_adult_single.png"):
    os.remove("AHC_adult_single.png")

#AHC clustering using Single Linkage on Adult dataset
C = linkage(X_ad, 'single')

# Plot the dendrogram for the single linkage
dendrogram(C)

#Save the plot as a png file
plt.savefig('AHC_adult_single.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Nguyen Quang Huy\OneDrive\Máy tính\machine-learning-two\labwork2\AHC.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Nguyen%20Quang%20Huy/OneDrive/M%C3%A1y%20t%C3%ADnh/machine-learning-two/labwork2/AHC.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>     os.remove("AHC_adult_single.png")
#      <a href='vscode-notebook-cell:/c%3A/Users/Nguyen%20Quang%20Huy/OneDrive/M%C3%A1y%20t%C3%ADnh/machine-learning-two/labwork2/AHC.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a> #AHC clustering using Single Linkage on Adult dataset
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Nguyen%20Quang%20Huy/OneDrive/M%C3%A1y%20t%C3%ADnh/machine-learning-two/labwork2/AHC.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a> C = linkage(X_ad, 'single')
#      <a href='vscode-notebook-cell:/c%3A/Users/Nguyen%20Quang%20Huy/OneDrive/M%C3%A1y%20t%C3%ADnh/machine-learning-two/labwork2/AHC.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a> # Plot the dendrogram for the single linkage
#      <a href='vscode-notebook-cell:/c%3A/Users/Nguyen%20Quang%20Huy/OneDrive/M%C3%A1y%20t%C3%ADnh/machine-learning-two/labwork2/AHC.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a> dendrogram(C)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\cluster\hierarchy.py:1045, in linkage(y, method, metric, optimal_ordering)
#    1042 if method not in _LINKAGE_METHODS:
#    1043     raise ValueError(f"Invalid method: {method}")
# -> 1045 y = _convert_to_double(np.asarray(y, order='c'))
#    1047 if y.ndim == 1:
#    1048     distance.is_valid_y(y, throw=True, name='y')
#
# ValueError: invalid __array_struct__
