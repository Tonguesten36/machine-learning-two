# %%
from ucimlrepo import fetch_ucirepo 

# fetch wine dataset 
wine = fetch_ucirepo(id=109) 
  
# data (as pandas dataframes) 
X_wine = wine.data.features 
y_wine = wine.data.targets 
  
# metadata 
print(wine.metadata) 
  
# variable information 
print(wine.variables)
# Out:
# {'uci_id': 109, 'name': 'Wine', 'repository_url': 'https://archive.ics.uci.edu/dataset/109/wine', 'data_url': 'https://archive.ics.uci.edu/static/public/109/data.csv', 'abstract': 'Using chemical analysis to determine the origin of wines', 'area': 'Physics and Chemistry', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 178, 'num_features': 13, 'feature_types': ['Integer', 'Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1992, 'last_updated': 'Mon Aug 28 2023', 'dataset_doi': '10.24432/C5PC7J', 'creators': ['Stefan Aeberhard', 'M. Forina'], 'intro_paper': {'title': 'Comparative analysis of statistical pattern recognition methods in high dimensional settings', 'authors': 'S. Aeberhard, D. Coomans, O. Vel', 'published_in': 'Pattern Recognition', 'year': 1994, 'url': 'https://www.semanticscholar.org/paper/83dc3e4030d7b9fbdbb4bde03ce12ab70ca10528', '
# ...

# %%
#Display the wine data
print("Wine Data")
X_wine.to_csv('wine.csv', index = False)
X_wine.head()
# Out:
# Wine Data
#    Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0    14.23       1.71  2.43               15.6        127           2.80
# 1    13.20       1.78  2.14               11.2        100           2.65
# 2    13.16       2.36  2.67               18.6        101           2.80
# 3    14.37       1.95  2.50               16.8        113           3.85
# 4    13.24       2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    0D280_0D315_of_diluted_wines  Proline
# ...

# %%
# Calculate the mean of wine dataset
print("Mean of Wine Data:")
X_wine.mean()
# Out:
# Mean of Wine Data:
# Alcohol                          13.000618
# Malicacid                         2.336348
# Ash                               2.366517
# Alcalinity_of_ash                19.494944
# Magnesium                        99.741573
# Total_phenols                     2.295112
# Flavanoids                        2.029270
# Nonflavanoid_phenols              0.361854
# Proanthocyanins                   1.590899
# Color_intensity                   5.058090
# Hue                               0.957449
# 0D280_0D315_of_diluted_wines      2.611685
# Proline                         746.893258
# dtype: float64

# %%
# Calculate the variance of wine dataset
print("Variance of Wine Data:")
X_wine.var()
# Out:
# Variance of Wine Data
# Alcohol                             0.659062
# Malicacid                           1.248015
# Ash                                 0.075265
# Alcalinity_of_ash                  11.152686
# Magnesium                         203.989335
# Total_phenols                       0.391690
# Flavanoids                          0.997719
# Nonflavanoid_phenols                0.015489
# Proanthocyanins                     0.327595
# Color_intensity                     5.374449
# Hue                                 0.052245
# 0D280_0D315_of_diluted_wines        0.504086
# Proline                         99166.717355
# dtype: float64

# %%
# Calculate the covariance of wine dataset
print("Covariance of Wine Data:")
X_wine.cov()
# Out:
# Covariance of Wine Data:
#                                  Alcohol  Malicacid        Ash  \
# Alcohol                         0.659062   0.085611   0.047115
# Malicacid                       0.085611   1.248015   0.050277
# Ash                             0.047115   0.050277   0.075265
# Alcalinity_of_ash              -0.841093   1.076332   0.406208
# Magnesium                       3.139878  -0.870780   1.122937
# Total_phenols                   0.146887  -0.234338   0.022146
# Flavanoids                      0.192033  -0.458630   0.031535
# Nonflavanoid_phenols           -0.015754   0.040733   0.006358
# Proanthocyanins                 0.063518  -0.141147   0.001516
# Color_intensity                 1.028283   0.644838   0.164654
# Hue                            -0.013313  -0.143326  -0.004682
# 0D280_0D315_of_diluted_wines    0.041698  -0.292447   0.000762
# Proline                       164.567185 -67.548867  19.319739
#
# ...

# %%
#Calculate the correlation of wine dataset
print("Correlation of Wine Data:")
X_wine.corr()
# Out:
# Correlation of Wine Data:
#                                Alcohol  Malicacid       Ash  \
# Alcohol                       1.000000   0.094397  0.211545
# Malicacid                     0.094397   1.000000  0.164045
# Ash                           0.211545   0.164045  1.000000
# Alcalinity_of_ash            -0.310235   0.288500  0.443367
# Magnesium                     0.270798  -0.054575  0.286587
# Total_phenols                 0.289101  -0.335167  0.128980
# Flavanoids                    0.236815  -0.411007  0.115077
# Nonflavanoid_phenols         -0.155929   0.292977  0.186230
# Proanthocyanins               0.136698  -0.220746  0.009652
# Color_intensity               0.546364   0.248985  0.258887
# Hue                          -0.071747  -0.561296 -0.074667
# 0D280_0D315_of_diluted_wines  0.072343  -0.368710  0.003911
# Proline                       0.643720  -0.192011  0.223626
#
#                               Alcalinity_of_ash  Magnesium  Total_phenols  \
# ...

# %%
#Find the most corelated couple of features in wine dataset
print("Most corelated couple of features in wine dataset:")
X_wine.corr().unstack().sort_values().drop_duplicates()

"""
The correlation between some two features is positive and some is negative.
The correlation between two features is not strong(range from 0 to 1).
"""
# Out:
# Most corelated couple of features in wine dataset:
# Malicacid                     Hue                            -0.561296
# Nonflavanoid_phenols          Flavanoids                     -0.537900
# Hue                           Color_intensity                -0.521813
# 0D280_0D315_of_diluted_wines  Nonflavanoid_phenols           -0.503270
# Total_phenols                 Nonflavanoid_phenols           -0.449935
#                                                                 ...
# Flavanoids                    Proanthocyanins                 0.652692
# 0D280_0D315_of_diluted_wines  Total_phenols                   0.699949
# Flavanoids                    0D280_0D315_of_diluted_wines    0.787194
#                               Total_phenols                   0.864564
# Alcohol                       Alcohol                         1.000000
# Length: 79, dtype: float64

# %%
#Apply PCA on wine dataset with 2 components
from sklearn.decomposition import PCA
from sklearn.datasets import load_wine
import matplotlib.pyplot as plt
import os

# Delete the pca of wine dataset image if it exists
if os.path.exists("wine_pca.png"):
  os.remove("wine_pca.png")
# Load the wine dataset
data = load_wine()
X = data.data
y = data.target

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c = y, edgecolor = 'none', alpha = 0.8,
            cmap = plt.cm.get_cmap('viridis', 3))
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar()
#Save the plot that shows the first two principal components of wine dataset as wine_pca.png
plt.savefig('wine_pca.png')
plt.show()
# Out:
# C:\Users\Nguyen Quang Huy\AppData\Local\Temp\ipykernel_7456\914275391.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('viridis', 3))

# %%
from sklearn.decomposition import PCA

# Calculate the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Print the explained variance ratio
print(f'Explained variance ratio by the first component: {explained_variance_ratio[0]}')
print(f'Explained variance ratio by the second component: {explained_variance_ratio[1]}')

# Calculate and print the total variation explained by the first two components
total_explained_variance = sum(explained_variance_ratio)
print(f'Total explained variance by the first two components: {total_explained_variance}')
# Out:
# Explained variance ratio by the first component: 0.9980912304918974
# Explained variance ratio by the second component: 0.0017359156247057507
# Total explained variance by the first two components: 0.9999221050741547

# %% [markdown]
# The explained variance ratio of the PCA object gives we the amount of variance explained by each of the selected components. This is equal to the eigenvalues of the covariance matrix of the data, divided by the total sum of the eigenvalues, which is equivalent to the total variance in the data.

# %%
#Apply PCA on wine dataset with n components(n > 2)
from sklearn.decomposition import PCA

# Input n from user(n > 2)
n = int(input("Enter the number of components: "))
if n == 2 or n < 2:
    print("Enter a number greater than 2")
    n = int(input("Enter the number of components: "))
# Apply PCA
pca = PCA(n_components = n)
X_pca = pca.fit_transform(X)

# Calculate the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Print the explained variance ratio of the first n components
for i in range(n):
    print(f'Explained variance ratio by the component {i+1}: {explained_variance_ratio[i]}')
# Calculate and print the total variation explained by the first two components
total_explained_variance = sum(explained_variance_ratio)
print(f'Total explained variance by the first {n} components: {total_explained_variance}')
# Out:
# Explained variance ratio by the component 1: 0.9980912304918974
# Explained variance ratio by the component 2: 0.0017359156247057507
# Explained variance ratio by the component 3: 9.495895755146106e-05
# Explained variance ratio by the component 4: 5.021735618215132e-05
# Total explained variance by the first 4 components: 0.9999723224303368

# %%
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import os
# Delete the pca wine dataset image if it exists
if os.path.exists("pca_wine_dataset.png"):
    os.remove("pca_wine_dataset.png")
# Load the wine dataset
wine = load_wine()
X = wine.data
y = wine.target

# Standardize the features to have zero mean and unit variance
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA to the standardized data
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X_scaled)

# Plot the first two principal components, using different colors for different classes
plt.figure(figsize=(8, 6))
for color, i, target_name in zip(['navy', 'turquoise', 'darkorange'], [0, 1, 2], wine.target_names):
    plt.scatter(principalComponents[y == i, 0], principalComponents[y == i, 1], color = color, alpha = .8, lw = 2,
                label = target_name)
plt.legend(loc = 'best', shadow = False, scatterpoints = 1)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA of Wine dataset')
#Save the plot that shows how the classes are separated by the first two principal components of the data as a png file
plt.savefig('pca_wine_dataset.png')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import os
# Delete the data distribution in 2D of wine dataset image if it exists
if os.path.exists("Data distribution in 2D of wine dataset.png"):
    os.remove("Data distribution in 2D of wine dataset.png")
#Visualize the data distribution in 2D of wine dataset
sns.histplot(X_wine)
#Save the plot that shows the data distribution in 2D of wine dataset as a png file
plt.savefig('Data distribution in 2D of wine dataset.png')
plt.show()
